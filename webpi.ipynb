# %%
import urllib2
import pandas as pd
from pandas import DataFrame
import json

# %%
html= urllib2.urlopen('http://api.nytimes.com/svc/elections/us/v3/finances/2016/president/totals.json?api-key=fc8ac3e86a593008d6cbf415e8b23091:19:69821416')

# %%
html
# Out:
# <addinfourl at 4549821864 whose fp = <socket._fileobject object at 0x10ed2f4d0>>

# %%
infile = json.load(html)

# %% [markdown]
# url = urllib2.urlopen(http://api.nytimes.com/svc/elections/us/{v3}/finances/{2016}/contributions/filing/{F3}[.json]?api-key={fc8ac3e86a593008d6cbf415e8b23091:19:69821416})

# %% [markdown]
# Is there something wrong with the way I'm putting in the API key?

# %%
infile
# Out:
# {u'base_uri': u'http://api.nytimes.com/svc/elections/us/v3/finances/2016/',
#  u'copyright': u'Copyright (c) 2015 The New York Times Company. All Rights Reserved.',
#  u'cycle': 2016,
#  u'results': [{u'associated_committees': [{u'candidate_committee': {u'candidate_election_year': 2016,
#       u'committee_designation': None,
#       u'committee_type': None,
#       u'created_at': None,
#       u'cycle': 2016,
#       u'fec_candidate_id': u'P00003392',
#       u'fec_committee_id': u'C00540997',
#       u'id': 3984,
#       u'linkage_id': None,
#       u'notes': u'Created by lib/tasks/committees.rake\n',
#       u'nyt_association': True,
#       u'updated_at': u'2015-09-22T15:49:52.129-04:00'},
#      u'committee': {u'address_one': None,
#       u'address_two': None,
#       u'candidate_id': 37,
#       u'category': None,
#       u'city': None,
#       u'cmte_type': None,
#       u'created_at': u'2015-06-02T21:13:07.286-04:00',
#       u'cycle': 2016,
#       u'designation': None,
# ...

# %% [markdown]
# name, candidate_name, cycle, cash_on_hand

# %%
name= []
candidate_name= []
cycle= []
cash_on_hand= []

for value in infile ['results']:
    name.append(value['name'])
    candidate_name.append(value['candidate_name'])
    #cycle.append(value['cycle'])
    cash_on_hand.append (value ['cash_on_hand'])

# %%
cash_on_hand
# Out:
# [32995172.39,
#  27119721.5,
#  11272534.13,
#  13778904.04,
#  10271129.09,
#  10975988.78,
#  2124155.52,
#  5549194.41,
#  985213.43,
#  254772.88,
#  1651309.13,
#  2641949.63,
#  1386447.39,
#  805986.83,
#  761410.96,
#  44553.59,
#  260939.01,
#  573935.6,
#  226525.92,
#  316765.34,
#  13570.55,
#  284526.27,
#  34384.4]

# %%
campaign= zip(name,cash_on_hand)
df= DataFrame( data= campaign, columns= ['Name','Cash On Hand'])
df
# Out:
#                Name  Cash On Hand
# 0   Hillary Clinton   32995172.39
# 1    Bernie Sanders   27119721.50
# 2        Ben Carson   11272534.13
# 3          Ted Cruz   13778904.04
# 4          Jeb Bush   10271129.09
# 5       Marco Rubio   10975988.78
# 6         Rand Paul    2124155.52
# 7     Carly Fiorina    5549194.41
# 8      Scott Walker     985213.43
# 9   Donald J. Trump     254772.88
# 10   Lindsey Graham    1651309.13
# 11      John Kasich    2641949.63
# 12   Chris Christie    1386447.39
# 13  Martin O'Malley     805986.83
# 14    Mike Huckabee     761410.96
# 15       Rick Perry      44553.59
# 16     Bobby Jindal     260939.01
# 17  Lawrence Lessig     573935.60
# 18    Rick Santorum     226525.92
# 19         Jim Webb     316765.34
# 20    George Pataki      13570.55
# 21   Lincoln Chafee     284526.27
# 22      Jim Gilmore      34384.40

# %% [markdown]
# Logan's code really inspired the conversion into a dataframe. One problem that I couldn't solve was extracting the name of the SuperPAC associated with each candidate. I tried to use 'nyt_name' but that just seemed to draw the candidate's name.
